# %% [markdown]
# # Título

# %% [markdown]
# ## sub-título

# %% [markdown]
# escribir algo de prueba

# %%
1+1
# Out:
# 2

# %% [markdown]
# # Imprimir código

# %%
x = "ema"

# %%
print(x)
# Out:
# ema

# %% [markdown]
# # Imprimir Tablas

# %%
import pandas as pd
tabla = pd.DataFrame(data = [[1,1],[2,4],[3,9]],
                     columns = ["numero","cuadrado"])
tabla
# Out:
#    numero  cuadrado
# 0       1         1
# 1       2         4
# 2       3         9

# %% [markdown]
# # Gráfico

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Imagen

# %% [markdown]
# ![R.jpg](attachment:3a870501-41a1-482b-a4aa-52a71d217abe.jpg)

# %% [markdown]
# ## Bullets o Conclusiones
# * primera conclusión
# * segunda conclusión
# * tercera conclusión

# %% [markdown]
# # Crear DataFrame con listas

# %%
lista_rrss = [
    ["Facebook",2006],
    ["Facebook",2006],
    ["Facebook",2006],
    ["Facebook",2006],
    ["Facebook",2006]
]

# %%
lista_rrss
# Out:
# [['Facebook', 2006],
#  ['Facebook', 2006],
#  ['Facebook', 2006],
#  ['Facebook', 2006],
#  ['Facebook', 2006]]

# %%
import pandas as pd
pd.DataFrame(lista_rrss,columns=["nombre","año de creación"])
# Out:
#      nombre  año de creación
# 0  Facebook             2006
# 1  Facebook             2006
# 2  Facebook             2006
# 3  Facebook             2006
# 4  Facebook             2006
