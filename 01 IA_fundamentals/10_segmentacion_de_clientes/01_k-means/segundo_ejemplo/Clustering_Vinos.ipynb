# %% [markdown]
# # Clustering con el Método K-Means

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# # Importamos los datos

# %%
vinos = pd.read_csv('vinito.csv')
vinos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Vino             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
vinos.head()
# Out:
#    Vino  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     2    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     3    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     4    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     5    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
# Quitamos primera columna:
vinos_variables = vinos.drop(['Vino'], axis = 1)

# %%
# Obtenemos estadisticos de vinos
vinos_variables.describe()
# Out:
#           Alcohol       Malic         Ash  Alcalinity   Magnesium     Phenols  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean    13.000618    2.336348    2.366517   19.494944   99.741573    2.295112
# std      0.811827    1.117146    0.274344    3.339564   14.282484    0.625851
# min     11.030000    0.740000    1.360000   10.600000   70.000000    0.980000
# 25%     12.362500    1.602500    2.210000   17.200000   88.000000    1.742500
# 50%     13.050000    1.865000    2.360000   19.500000   98.000000    2.355000
# 75%     13.677500    3.082500    2.557500   21.500000  107.000000    2.800000
# max     14.830000    5.800000    3.230000   30.000000  162.000000    3.880000
#
#        Flavanoids  Nonflavanoids  Proanthocyanins       Color         Hue  \
# count  178.000000     178.000000       178.000000  178.000000  178.000000
# mean     2.029270       0.361854         1.590899    5.058090    0.957449
# ...

# %%
# Normalizamos para convertir los valores para que se encuentren en un mismo rango
vinos_norm = (vinos_variables-vinos_variables.min())/(vinos_variables.max()-vinos_variables.min())
vinos_norm
# Out:
#       Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0    0.842105  0.191700  0.572193    0.257732   0.619565  0.627586
# 1    0.571053  0.205534  0.417112    0.030928   0.326087  0.575862
# 2    0.560526  0.320158  0.700535    0.412371   0.336957  0.627586
# 3    0.878947  0.239130  0.609626    0.319588   0.467391  0.989655
# 4    0.581579  0.365613  0.807487    0.536082   0.521739  0.627586
# ..        ...       ...       ...         ...        ...       ...
# 173  0.705263  0.970356  0.582888    0.510309   0.271739  0.241379
# 174  0.623684  0.626482  0.598930    0.639175   0.347826  0.282759
# 175  0.589474  0.699605  0.481283    0.484536   0.543478  0.210345
# 176  0.563158  0.365613  0.540107    0.484536   0.543478  0.231034
# 177  0.815789  0.664032  0.737968    0.716495   0.282609  0.368966
#
#      Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  Dilution  \
# 0      0.573840       0.283019         0.593060  0.372014  0.455285  0.970696
# ...

# %%
vinos_norm.describe()
# Out:
#           Alcohol       Malic         Ash  Alcalinity   Magnesium     Phenols  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     0.518584    0.315484    0.538244    0.458502    0.323278    0.453487
# std      0.213639    0.220780    0.146708    0.172142    0.155244    0.215811
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.350658    0.170455    0.454545    0.340206    0.195652    0.262931
# 50%      0.531579    0.222332    0.534759    0.458763    0.304348    0.474138
# 75%      0.696711    0.462945    0.640374    0.561856    0.402174    0.627586
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Flavanoids  Nonflavanoids  Proanthocyanins       Color         Hue  \
# count  178.000000     178.000000       178.000000  178.000000  178.000000
# mean     0.356386       0.437460         0.372523    0.322363    0.388170
# ...

# %% [markdown]
#   # Busqueda de la cantidad optima de clusters, suponiendo que no tenemos un criterio para decidir cuantos cluesters a crear y que ampoco sabemos cual sería la cantidad óptima de clusters a formar.
#
# ## Se usa el método llamado codo de jambú. Que consiste en ir creando diferentes cantidades de clusters y calculando que tan similares son los individuos dentro de los mismose ir plasmando esta infromación en una gráfica.
#
# ## Mientras más similares son estos, más distantes se encontraran los clusters que se formen que es lo que buscamos en el clutering, la formación de grupos ien delimitados que contengn individuos cuya distancia entre ellos sea la menor posible.
#
# ## Para medir esta distancia se utiliza la suma de los cuadrados de cada grupo también llamada WCSS, por sus siglas en inglés Within-Cluster-Sum-of-Squares.

# %% [markdown]
# #### Calculando que tan similares son los individuos dentro de los cluesters

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters = i, max_iter = 300)
    kmeans.fit(vinos_norm) # Aquí anota que aplica K-means a la base de datos
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Danko\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Danko\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Danko\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# # Graficando los resultados de WCSS para formar el Codo de Jambú y obtener la cantidad de Clusters necesarios.

# %%
plt.plot(range(1,11),wcss)
plt.title('Codo de Jambú')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS') # Es un indicador de qué tan similares son los individuos dentro de los clusters
plt.show()

# %% [markdown]
# ### Se observa en el gráfico que a medida que avanzan los números de clusters, disminuyen los WCSS. También se puede notar que dejan de decrecer de forma drástica en número de clusters igual a 3, para decrecer lentamente. Esto significa que solo necesitamos 3 clusters para no tener demasiadas particiones.

# %% [markdown]
# # Aplicando el modelo k-means a la base de datos

# %%
clustering = KMeans(n_clusters = 3, max_iter = 300)
clustering.fit(vinos_norm)
# Out:
# C:\Users\Danko\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %% [markdown]
# # Agregando la clasificación al archivo original.

# %%
vinos['KMeans_Clusters'] = clustering.labels_ # Los resultados del clustering se guardan en labels_ dentro del modelo
vinos.head()
# Out:
#    Vino  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     2    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     3    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     4    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     5    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  \
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735
#
#    KMeans_Clusters
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# # Visualización de los clusters
# ### Aplicaremos el análisis de componentes principales (PCA) para darnos una unda idea de cómo se formaron los clusters.

# %%
 from sklearn.decomposition import PCA
    
pca = PCA(n_components=2)
pca_vinos = pca.fit_transform(vinos_norm)
pca_vinos_df = pd.DataFrame(data = pca_vinos, columns = ['Componente_1', 'Componente_2'])
pca_nombres_vinos = pd.concat([pca_vinos_df, vinos[['KMeans_Clusters']]], axis = 1)

pca_nombres_vinos
# Out:
#      Componente_1  Componente_2  KMeans_Clusters
# 0       -0.706336     -0.253193                0
# 1       -0.484977     -0.008823                0
# 2       -0.521172     -0.189187                0
# 3       -0.821644     -0.580906                0
# 4       -0.202546     -0.059467                0
# ..            ...           ...              ...
# 173      0.739510     -0.471901                1
# 174      0.581781     -0.348366                1
# 175      0.626313     -0.546857                1
# 176      0.572991     -0.425516                1
# 177      0.701764     -0.513505                1
#
# [178 rows x 3 columns]

# %%
# Coloreamos los clusters

fig = plt.figure(figsize = (6,6)) #creamos una figura de 6x6

ax = fig.add_subplot(1,1,1) #indicamos que haremos solo un gráfico dentro de la figura
ax.set_xlabel('Componente 1', fontsize = 15) #nombres del eje x
ax.set_ylabel('Componente 2', fontsize = 15) #nombre del eje y
ax.set_title('Componentes Principales', fontsize = 20) #nombre del gráfico

color_theme = np.array(['blue', 'green', 'orange']) #creamos un array con tres colores para cada cluster
ax.scatter(x = pca_nombres_vinos.Componente_1, y = pca_nombres_vinos.Componente_2,
          c = color_theme[pca_nombres_vinos.KMeans_Clusters], s = 50)
#dibujar los puntos que representarán los vinos con scatter
#agregamos los valores de las columnas componentes
#usamos el parámetro c para indicarle los colores que deseamos para los puntos
# esta información se encuentra en KMeans_Clusters del objeto pca_nombres_vinos
# el tamaño de los puntos a graficar será de 50
plt.show()

# %% [markdown]
# # Grabamos los clusters en el disco duro

# %%
vinos.to_csv('vinos_K-Means.csv')
